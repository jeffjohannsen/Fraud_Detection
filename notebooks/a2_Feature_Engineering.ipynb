# %% [markdown]
# ## Imports and Global Settings

# %%
import pandas as pd

pd.set_option('display.max_columns', 500)

# %% [markdown]
# ## Load Data

# %%
original_data = pd.read_json('../data/clean_data.json', orient='records', lines=True)
data = original_data.copy()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11469 entries, 0 to 11468
# Data columns (total 42 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   approx_payout_date  11469 non-null  int64
#  1   body_length         11469 non-null  int64
#  2   channels            11469 non-null  int64
#  3   country             11469 non-null  object
#  4   currency            11469 non-null  object
#  5   delivery_method     11469 non-null  int64
#  6   description         11469 non-null  object
#  7   email_domain        11469 non-null  object
#  8   event_created       11469 non-null  int64
#  9   event_end           11469 non-null  int64
#  10  event_start         11469 non-null  int64
#  11  fb_published        11469 non-null  int64
#  12  gts                 11469 non-null  float64
#  13  has_analytics       11469 non-null  int64
#  14  has_header          11469 non-null  int64
#  15  has_logo            11469 non-null  int64
#  16  listed              11469 non-null  int64
#  17  name                11469 non-null  object
#  18  name_length         11469 non-null  int64
#  19  num_order           11469 non-null  int64
#  20  num_payouts         11469 non-null  int64
#  21  object_id           11469 non-null  int64
#  22  org_desc            11469 non-null  object
#  23  org_facebook        11469 non-null  int64
#  24  org_name            11469 non-null  object
#  25  org_twitter         11469 non-null  int64
#  26  payee_name          11469 non-null  object
#  27  payout_type         11469 non-null  object
#  28  previous_payouts    11469 non-null  object
#  29  sale_duration       11469 non-null  int64
#  30  sale_duration2      11469 non-null  int64
#  31  show_map            11469 non-null  int64
#  32  ticket_types        11469 non-null  object
#  33  user_age            11469 non-null  int64
#  34  user_created        11469 non-null  int64
#  35  user_type           11469 non-null  int64
#  36  venue_country       11469 non-null  object
#  37  venue_latitude      11469 non-null  float64
#  38  venue_longitude     11469 non-null  float64
#  39  venue_name          11469 non-null  object
#  40  venue_state         11469 non-null  object
#  41  is_fraud            11469 non-null  bool
# dtypes: bool(1), float64(3), int64(24), object(14)
# memory usage: 3.6+ MB

# %%
data.head()
# Out:
#    approx_payout_date  body_length  channels country currency  \
# 0       1355097600000        43227         8      CA      CAD
# 1       1334775600000          664         8      US      USD
# 2       1380684600000          923        11      US      USD
# 3       1362142800000         4417        11      IE      EUR
# 4       1358746200000         2505         8      US      USD
#
#    delivery_method                                        description  \
# 0                1  <p class="MsoNormal"><span style="color: #3333...
# 1                1  Please join us for the IIDA Student Career Day...
# 2                0  <p style="text-align: justify;" align="LEFT">&...
# 3                0  <p><strong>&nbsp;<span style="font-family: hel...
# 4                1  <p style="text-align: center;"><strong>ONLY ON...
#
#         email_domain  event_created      event_end    event_start  \
# 0           cedec.ca  1351629944000  1354665600000  1354654800000
# 1          yahoo.com  1328839445000  1334343600000  1334340000000
# 2  projectgradli.org  1374514499000  1380252600000  1380243600000
# 3          gmail.com  1360608512000  1361710800000  1361680200000
# 4          gmail.com  1353197931000  1358314200000  1358308800000
#
#    fb_published      gts  has_analytics  has_header  has_logo  listed  \
# 0             0    85.29              0           0         1       1
# 1             0    50.00              0          -1         0       1
# 2             0  9550.00              0          -1         1       1
# 3             0  1813.36              0          -1         1       0
# 4             0   105.44              0           0         1       1
#
#                                                 name  name_length  num_order  \
# 0     Ten Follow-Up Mistakes Your Competition Loves            46          5
# 1  Student Career Day 2012: Speed Mentoring - 11A...           57          8
# 2                           DREAMING UNDER THE STARS           24          5
# 3                                       King of Ping           12         51
# 4  Everyone Communicates Few Connect MasterMind G...           50          1
#
#    num_payouts  object_id                                           org_desc  \
# 0           31    4710425  <p><strong>CEDEC Small Business Support Networ...
# 1            6    2930589  <p>The IIDA Cleveland Akron City Center connec...
# 2            0    7540419  <p style="text-align: justify;" align="LEFT"><...
# 3            1    5481976  <p>Mabos is a multi-purpose art space with a m...
# 4            1    4851467  <p><span style="font-family: Arial, Helvetica,...
#
#    org_facebook                                           org_name  \
# 0             9               CEDEC Small Business Support Network
# 1            53                   Cleveland Akron IIDA City Center
# 2             0                           Project GRAD Long island
# 3            27                                             mabos
# 4            14  Kim D. Moore - Coach, Teacher and Speaker with...
#
#    org_twitter    payee_name payout_type  \
# 0            9       Unknown         ACH
# 1            0       Unknown         ACH
# 2            0       Unknown         ACH
# 3           11       Unknown         ACH
# 4           10  Kim D. Moore       CHECK
#
#                                     previous_payouts  sale_duration  \
# 0  [{'name': '', 'created': '2011-01-13 00:00:00'...             35
# 1  [{'name': '', 'created': '2011-10-25 01:11:37'...             61
# 2  [{'name': '', 'created': '2013-10-01 03:13:01'...             66
# 3  [{'name': '', 'created': '2013-01-05 03:14:55'...             12
# 4  [{'name': 'Kim D. Moore', 'created': '2012-10-...             57
#
#    sale_duration2  show_map  \
# 0              35         1
# 1              64         1
# 2              66         1
# 3              12         1
# 4              59         0
#
#                                         ticket_types  user_age   user_created  \
# 0  [{'event_id': 4710425, 'cost': 13.11, 'availab...       722  1289255732000
# 1  [{'event_id': 2930589, 'cost': 0.0, 'availabil...       205  1311116195000
# 2  [{'event_id': 7540419, 'cost': 0.0, 'availabil...         0  1374514498000
# 3  [{'event_id': 5481976, 'cost': 16.74, 'availab...        50  1356308239000
# 4  [{'event_id': 4851467, 'cost': 99.0, 'availabi...      1029  1264268063000
#
#    user_type venue_country  venue_latitude  venue_longitude  \
# 0          3            CA       45.047497       -73.584455
# 1          3            US       41.499465       -81.682202
# 2          1            US       40.728012       -73.601930
# 3          3            IE       53.343803        -6.232139
# 4          4       Unknown       -1.000000        -1.000000
#
#                       venue_name    venue_state  is_fraud
# 0               Café Hemmingford         Quebec     False
# 1                      Ohio Desk             OH     False
# 2  The Cradle of Aviation Museum             NY     False
# 3                         mabos   County Dublin     False
# 4                        Unknown        Unknown     False

# %% [markdown]
# ## Explore and Expand Nested Features

# %% [markdown]
# Aggregating data from within previous_payouts.

# %%
def payouts_sum(x):
    total = 0
    for payout in x:
        total += payout['amount']
    return total

data['num_previous_payouts'] = data['previous_payouts'].apply(lambda x: len(x))
data['previous_payouts_total'] = data['previous_payouts'].apply(payouts_sum)

data = data.drop(columns=['previous_payouts'])

# %% [markdown]
# Aggregating data from ticket_types.

# %%
def get_tickets_available(x):
    total = 0
    for ticket_type in x:
        total += ticket_type['quantity_total']
    return total

def get_total_ticket_value(x):
    total = 0
    for ticket_type in x:
        total += (ticket_type['quantity_total'] * ticket_type['cost'])
    return total

data['num_ticket_types'] = data['ticket_types'].apply(lambda x: len(x))
data['num_tickets_available'] = data['ticket_types'].apply(get_tickets_available)
data['total_ticket_value'] = data['ticket_types'].apply(get_total_ticket_value)
data['avg_ticket_cost'] = data['total_ticket_value'] / data['num_tickets_available']

data = data.drop(columns=['ticket_types'])

# %% [markdown]
# ## Composite Features from Datetimes

# %%
datetime_features = [
        "approx_payout_date",
        "event_created",
        "event_end",
        "event_start",
        "user_created",
    ]
for feature in datetime_features:
    data[feature] = pd.to_datetime(data[feature], unit="ms")

# %%
data['days_from_event_created_till_start'] = (data['event_start'] - data['event_created']).dt.days

# %%
datetime_features = ['approx_payout_date', 'event_created', 'event_end',
                     'event_start', 'user_created']
data = data.drop(columns=datetime_features)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11469 entries, 0 to 11468
# Data columns (total 42 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   body_length                         11469 non-null  int64
#  1   channels                            11469 non-null  int64
#  2   country                             11469 non-null  object
#  3   currency                            11469 non-null  object
#  4   delivery_method                     11469 non-null  int64
#  5   description                         11469 non-null  object
#  6   email_domain                        11469 non-null  object
#  7   fb_published                        11469 non-null  int64
#  8   gts                                 11469 non-null  float64
#  9   has_analytics                       11469 non-null  int64
#  10  has_header                          11469 non-null  int64
#  11  has_logo                            11469 non-null  int64
#  12  listed                              11469 non-null  int64
#  13  name                                11469 non-null  object
#  14  name_length                         11469 non-null  int64
#  15  num_order                           11469 non-null  int64
#  16  num_payouts                         11469 non-null  int64
#  17  object_id                           11469 non-null  int64
#  18  org_desc                            11469 non-null  object
#  19  org_facebook                        11469 non-null  int64
#  20  org_name                            11469 non-null  object
#  21  org_twitter                         11469 non-null  int64
#  22  payee_name                          11469 non-null  object
#  23  payout_type                         11469 non-null  object
#  24  sale_duration                       11469 non-null  int64
#  25  sale_duration2                      11469 non-null  int64
#  26  show_map                            11469 non-null  int64
#  27  user_age                            11469 non-null  int64
#  28  user_type                           11469 non-null  int64
#  29  venue_country                       11469 non-null  object
#  30  venue_latitude                      11469 non-null  float64
#  31  venue_longitude                     11469 non-null  float64
#  32  venue_name                          11469 non-null  object
#  33  venue_state                         11469 non-null  object
#  34  is_fraud                            11469 non-null  bool
#  35  num_previous_payouts                11469 non-null  int64
#  36  previous_payouts_total              11469 non-null  float64
#  37  num_ticket_types                    11469 non-null  int64
#  38  num_tickets_available               11469 non-null  int64
#  39  total_ticket_value                  11469 non-null  float64
#  40  avg_ticket_cost                     11374 non-null  float64
#  41  days_from_event_created_till_start  11469 non-null  int64
# dtypes: bool(1), float64(6), int64(23), object(12)
# memory usage: 3.6+ MB

# %% [markdown]
# ## Categorical Features
